# %% [markdown]
# # Exercises for Main Session 1 - Meeting Python in Anaconda

# %% [markdown]
# ### 1. Open Anaconda Python

# %%
#Code

# %% [markdown]
# ### 2. Start Anaconda Prompt

# %%
#Code

# %% [markdown]
# ### 3. Check all libraries installed in Python Base in Anaconda Prompt

# %%
#Code

# %% [markdown]
# ### 4. Check all libraries installed using Anaconda Environments

# %%
#Code

# %% [markdown]
# ### 5. Create a new Environment called CDAMP

# %%
#Code

# %% [markdown]
# ### 6. Install Pandas in the CDAMP environment

# %%
#Code

# %% [markdown]
# ### 7. Install Visual Code

# %%
#Code

# %% [markdown]
# ### 8. How to get the first 20 values of all columns into our dataframe?

# %%
#Code

# %% [markdown]
# ### 9. How to obtain a global dataframe description?

# %%
#Code

# %% [markdown]
# ### 10. How to get a frequency of labels into a dataframe's labels column?

# %%
#Code

# %% [markdown]
# ### Solutions

# %%
#1. 
import pandas as pd
import sqlite3

# %%
#2
df_excel = pd.read_excel('./data/yahoo.xlsx')

# %%
#3
sd_sas = pd.read_sas('./data/DCSKINPRODUCT.sas7bdat')

# %%
#4.
conn = sqlite3.connect('./data/company_balancesheet_database.db')
df_sql = pd.read_sql_query("SELECT * FROM balancesheet", conn)

# %%
#5.
list_dfs = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')

# %%
#6.
df_json = pd.read_json('./data/default.json')

# %%
#7.
df_excel.shape
# Out:
# (86, 65)

# %%
#8.
df_excel.head(20)
# Out:
#     Unnamed: 0 ticker country      sector RefIndex Market Cap  \
# 0            0   GOOG     USA  Technology      SPY     818.1B
# 1            1   MSFT     USA  Technology      SPY    879.31B
# 2            2     FB     USA  Technology      SPY    477.58B
# 3            3      T     USA  Technology      SPY    246.25B
# 4            4   ORCL     USA  Technology      SPY    203.99B
# 5            5     VZ     USA  Technology      SPY    221.22B
# 6            6    TSM     USA  Technology      SPY    224.73B
# 7            7   INTC     USA  Technology      SPY     216.3B
# 8            8   CSCO     USA  Technology      SPY    221.44B
# 9            9    IBM     USA  Technology      SPY    136.94B
# 10          10   NVDA     USA  Technology      SPY    161.55B
# 11          11    ACN     USA  Technology      SPY    110.61B
# 12          12    TXN     USA  Technology      SPY    106.75B
# 13          13    VOD     USA  Technology      SPY     58.53B
# ...

# %%
df_excel.describe()
# Out:
#        Unnamed: 0  Forward P/E  PEG Ratio  Price/Sales  Price/Book  \
# count   86.000000    78.000000  78.000000    85.000000   80.000000
# mean    42.500000    19.436026   2.523846     4.195412    8.996250
# std     24.969982    15.137857   6.094044     3.223754   15.114115
# min      0.000000     5.870000  -2.050000     0.250000    0.000000
# 25%     21.250000    12.157500   1.352500     2.420000    2.137500
# 50%     42.500000    16.470000   1.770000     3.710000    4.610000
# 75%     63.750000    19.920000   2.330000     4.670000   10.205000
# max     85.000000   104.420000  54.200000    16.560000  118.510000
#
#        Enterprise Value/Revenue  Enterprise Value/EBITDA  Diluted EPS  \
# count                 85.000000                70.000000    85.000000
# mean                   3.905765                14.263714     4.395176
# std                    4.008729                22.861582     5.382589
# min                   -7.910000              -136.890000   -16.140000
# ...

# %%
df_excel['Price/Sales'].value_counts()
# Out:
# 3.74    3
# 2.87    2
# 4.18    2
# 0.83    1
# 1.82    1
#        ..
# 3.71    1
# 5.94    1
# 0.25    1
# 3.22    1
# 4.22    1
# Name: Price/Sales, Length: 81, dtype: int64
